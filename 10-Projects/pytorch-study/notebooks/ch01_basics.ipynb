# %% [markdown]
# <a href="https://colab.research.google.com/github/hyoungwonkang/python_prac_with_obsidian/blob/main/10-Projects/pytorch-study/notebooks/ch01_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import sys, platform

print("=" * 50)
print(f"Python      : {sys.version.split()[0]}")
print(f"Platform    : {platform.machine()} {platform.system()}")
print(f"PyTorch     : {torch.__version__}")
print(f"CUDA 사용가능: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA 버전   : {torch.version.cuda}")
    print(f"GPU 이름    : {torch.cuda.get_device_name(0)}")
    print(f"GPU 메모리  : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
print("=" * 50)
# Out:
# ...
# Python      : 3.12.13
# Platform    : x86_64 Linux
# PyTorch     : 2.11.0+cu128
# CUDA 사용가능: True
# CUDA 버전   : 12.8
# GPU 이름    : Tesla T4
# GPU 메모리  : 15.6 GB
# ...

# %%
device = (
      "cuda" if torch.cuda.is_available()
      else "mps" if torch.backends.mps.is_available()
      else "cpu"
)
print(f"선택된 디바이스: {device}")

x = torch.tensor([1.0, 2.0, 3.0], device=device)
y = torch.tensor([4.0, 5.0, 6.0], device=device)
print(f"x + y       : {x + y}")
# Out:
# 선택된 디바이스: cuda
# x + y       : tensor([5., 7., 9.], device='cuda:0')
